# %% [markdown]
# # Erode

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('../Data/Images/opencv_inv.png',0)

cv2.imshow('Original', img)
cv2.waitKey(0)

plt.imshow(img, cmap='gray')
plt.title('Original')
plt.show()

kernel = np.ones((5,5),np.uint8)
erosion = cv2.erode(img,kernel,iterations = 1)


cv2.imshow('Erosion', erosion)
cv2.waitKey(0)

plt.imshow(erosion, cmap='gray')
plt.title('Erosion')
plt.show()

cv2.destroyAllWindows()

# %% [markdown]
# # Dilate

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('../Data/Images/opencv_inv.png',0)

cv2.imshow('Original', img)
cv2.waitKey(0)

plt.imshow(img, cmap='gray')
plt.title('Original')
plt.show()

kernel = np.ones((5,5),np.uint8)
dilation = cv2.dilate(img,kernel,iterations = 1)


cv2.imshow('Dilation', dilation)
cv2.waitKey(0)

plt.imshow(dilation, cmap='gray')
plt.title('Dilation')
plt.show()

cv2.destroyAllWindows()

# %% [markdown]
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# img = cv2.imread('../Data/Images/numbers.jpg',0)
#
# cv2.imshow('Original', img)
# cv2.waitKey(0)
#
# plt.imshow(img, cmap='gray')
# plt.title('Original')
# plt.show()
#
# ret, img = cv2.threshold(img, 140, 200, cv2.THRESH_BINARY_INV)
#
# cv2.imshow('Thresold', img)
# cv2.waitKey(0)
#
# plt.imshow(img, cmap='gray')
# plt.title('Thresold')
# plt.show()
#
# img = cv2.GaussianBlur(img,(7,7),0)
#
# cv2.imshow('After Blur', img)
# cv2.waitKey(0)
#
# plt.imshow(img, cmap='gray')
# plt.title('After Blur')
# plt.show()
#
# kernel = np.ones((7,7),np.uint8)
# dilation = cv2.dilate(img,kernel,iterations = 1)
#
#
# cv2.imshow('Dilation', dilation)
# cv2.waitKey(0)
#
# plt.imshow(dilation, cmap='gray')
# plt.title('Dilation')
# plt.show()
#
# cv2.destroyAllWindows()

# %% [markdown]
# # Resources
#
# https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_morphological_ops/py_morphological_ops.html#morphological-ops
