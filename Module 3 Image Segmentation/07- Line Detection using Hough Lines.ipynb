# %% [markdown]
# # Hough Lines

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


image = cv2.imread('../Data/Images/soduku.jpg')

cv2.imshow('Original', image)
cv2.waitKey(0)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original')
plt.show()

gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray,50,150,apertureSize = 3)


lines = cv2.HoughLinesP(edges, 1, np.pi / 180, 230, 100, 100, 30)

for x in range(0, len(lines)):
    for x1,y1,x2,y2 in lines[x]:
        cv2.line(image,(x1,y1),(x2,y2),(0,255,0),3)

cv2.imshow('Probabilistic Hough Lines', image)
cv2.waitKey(0)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Probabilistic Hough Lines')
plt.show()

cv2.destroyAllWindows()

# %% [markdown]
# # Resources
#
# https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_houghlines/py_houghlines.html#hough-lines
#
# https://www.youtube.com/watch?v=4zHbI-fFIlI
#
#
# https://www.youtube.com/watch?v=uDB2qGqnQ1g&list=PL4B3F8D4A5CAD8DA3&index=28
#
# https://www.youtube.com/watch?v=o-n7NoLArcs&list=PL4B3F8D4A5CAD8DA3&index=29
