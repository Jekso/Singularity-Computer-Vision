# %% [markdown]
# # Import OpenCV Library

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Read Image

# %%
image = cv2.imread('../Data/Images/input.jpg')

cv2.imshow('Image', image)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Hello World')
plt.show()

cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # Get Imge Shape (Width & Height)

# %%
image.shape
# Out:
# (830, 1245, 3)

# %%
print("Height is: " + str(image.shape[0]) + " Pixel")
print("Width is: " + str(image.shape[1]) + " Pixel")
print("Channels size are : " + str(image.shape[2]) + " Channels")
# Out:
# Height is: 830 Pixel
# Width is: 1245 Pixel
# Channels size are : 3 Channels

# %%
print(image)
# Out:
# [[[12 18 29]
#   [12 18 31]
#   [11 17 30]
#   ...
#   [21 24 38]
#   [21 24 38]
#   [21 24 38]]
#
#  [[12 18 29]
#   [12 18 31]
#   [12 18 31]
#   ...
#   [21 24 38]
#   [21 24 38]
#   [21 24 38]]
#
#  [[12 18 29]
#   [12 18 31]
#   [12 18 31]
#   ...
#   [21 24 38]
#   [21 24 38]
#   [21 24 38]]
#
#  ...
#
#  [[ 4  7 12]
#   [ 4  7 12]
#   [ 4  7 12]
#   ...
#   [18 23 38]
#   [19 24 39]
#   [20 25 40]]
#
#  [[ 3  6 11]
#   [ 3  6 11]
#   [ 3  6 11]
#   ...
#   [18 23 38]
#   [19 24 39]
#   [20 25 40]]
#
#  [[ 3  6 11]
#   [ 3  6 11]
#   [ 2  5 10]
#   ...
#   [18 23 38]
#   [18 23 38]
#   [19 24 39]]]

# %%
print(image[10,20])
print(image[100,250])
# Out:
# [12 18 31]
# [16 23 40]

# %% [markdown]
# # Write Image

# %%
cv2.imwrite('../Data/Output/output.jpg', image)
# Out:
# True

# %% [markdown]
# # Resources
# https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_gui/py_image_display/py_image_display.html#display-image
