# %% [markdown]
# # Grayscaling

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('../Data/Images/input.jpg')

print(image.shape)

cv2.imshow('BGR Image', image)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('BGR Image')
plt.show()

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# (830, 1245, 3)

# %%
gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

print(gray_img.shape)

cv2.imshow('Gray Image', gray_img)

plt.imshow(gray_img, cmap='gray')
plt.title('Gray Image')
plt.show()

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# (830, 1245)

# %% [markdown]
# # HSV

# %%
image = cv2.imread('../Data/Images/input.jpg')

hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

cv2.imshow('HSV image', hsv_image)
cv2.waitKey()

cv2.imshow('Hue channel', hsv_image[:, :, 0])
cv2.waitKey()

cv2.imshow('Saturation channel', hsv_image[:, :, 1])
cv2.waitKey()

cv2.imshow('Value channel', hsv_image[:, :, 2])
cv2.waitKey()

cv2.destroyAllWindows()

# %% [markdown]
# ## we will learn Later how to use HSV color space to FILTER images by color to track objects

# %% [markdown]
# # Resources
#
# https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_colorspaces/py_colorspaces.html#converting-colorspaces
#
# https://handmap.github.io/hsv-vs-rgb/
