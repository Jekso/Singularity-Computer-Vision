# %% [markdown]
# # Splitting Image Channels

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('../Data/Images/input.jpg')
cv2.imshow('Main Image', img)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Main Image')
plt.show()

print(img)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# [[[12 18 29]
#   [12 18 31]
#   [11 17 30]
#   ...
#   [21 24 38]
#   [21 24 38]
#   [21 24 38]]
#
#  [[12 18 29]
#   [12 18 31]
#   [12 18 31]
#   ...
#   [21 24 38]
#   [21 24 38]
#   [21 24 38]]
#
#  [[12 18 29]
#   [12 18 31]
#   [12 18 31]
#   ...
#   [21 24 38]
#   [21 24 38]
#   [21 24 38]]
#
#  ...
#
#  [[ 4  7 12]
#   [ 4  7 12]
#   [ 4  7 12]
#   ...
#   [18 23 38]
#   [19 24 39]
#   [20 25 40]]
#
#  [[ 3  6 11]
#   [ 3  6 11]
#   [ 3  6 11]
#   ...
#   [18 23 38]
#   [19 24 39]
#   [20 25 40]]
#
#  [[ 3  6 11]
#   [ 3  6 11]
#   [ 2  5 10]
#   ...
#   [18 23 38]
#   [18 23 38]
#   [19 24 39]]]

# %%
b, g, r = cv2.split(img)

cv2.imshow('Blue Channel', b)
cv2.waitKey()

cv2.imshow('Green Channel', g)
cv2.waitKey()

cv2.imshow('Red Channel', r)
cv2.waitKey()

plt.imshow(cv2.cvtColor(b, cv2.COLOR_GRAY2RGB))
plt.title('Blue Channel')
plt.show()

plt.imshow(cv2.cvtColor(g, cv2.COLOR_GRAY2RGB))
plt.title('Green Channel')
plt.show()

plt.imshow(cv2.cvtColor(r, cv2.COLOR_GRAY2RGB))
plt.title('Red Channel')
plt.show()

print(b)
# print(g)
# print(r)


cv2.destroyAllWindows()
# Out:
# [[12 12 11 ... 21 21 21]
#  [12 12 12 ... 21 21 21]
#  [12 12 12 ... 21 21 21]
#  ...
#  [ 4  4  4 ... 18 19 20]
#  [ 3  3  3 ... 18 19 20]
#  [ 3  3  2 ... 18 18 19]]

# %% [markdown]
# # Merge Channels

# %%
img = cv2.merge([b,g,r])

cv2.imshow('Merged', img)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Merged')
plt.show()

print(img)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# [[[12 18 29]
#   [12 18 31]
#   [11 17 30]
#   ...
#   [21 24 38]
#   [21 24 38]
#   [21 24 38]]
#
#  [[12 18 29]
#   [12 18 31]
#   [12 18 31]
#   ...
#   [21 24 38]
#   [21 24 38]
#   [21 24 38]]
#
#  [[12 18 29]
#   [12 18 31]
#   [12 18 31]
#   ...
#   [21 24 38]
#   [21 24 38]
#   [21 24 38]]
#
#  ...
#
#  [[ 4  7 12]
#   [ 4  7 12]
#   [ 4  7 12]
#   ...
#   [18 23 38]
#   [19 24 39]
#   [20 25 40]]
#
#  [[ 3  6 11]
#   [ 3  6 11]
#   [ 3  6 11]
#   ...
#   [18 23 38]
#   [19 24 39]
#   [20 25 40]]
#
#  [[ 3  6 11]
#   [ 3  6 11]
#   [ 2  5 10]
#   ...
#   [18 23 38]
#   [18 23 38]
#   [19 24 39]]]

# %%
img = cv2.merge([b+200, g, r])
cv2.imshow('Merged with increase blue', img)
cv2.waitKey()

img2 = cv2.merge([b, g+200, r])
cv2.imshow('Merged with increase green', img2)
cv2.waitKey()

img3 = cv2.merge([b, g, r+200])
cv2.imshow('Merged with increase red', img3)
cv2.waitKey()


plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Merged with increase blue')
plt.show()

plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
plt.title('Merged with increase green')
plt.show()

plt.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))
plt.title('Merged with increase red')
plt.show()

print(img)

cv2.destroyAllWindows()
# Out:
# [[[212  18  29]
#   [212  18  31]
#   [211  17  30]
#   ...
#   [221  24  38]
#   [221  24  38]
#   [221  24  38]]
#
#  [[212  18  29]
#   [212  18  31]
#   [212  18  31]
#   ...
#   [221  24  38]
#   [221  24  38]
#   [221  24  38]]
#
#  [[212  18  29]
#   [212  18  31]
#   [212  18  31]
#   ...
#   [221  24  38]
#   [221  24  38]
#   [221  24  38]]
#
#  ...
#
#  [[204   7  12]
#   [204   7  12]
#   [204   7  12]
#   ...
#   [218  23  38]
#   [219  24  39]
#   [220  25  40]]
#
#  [[203   6  11]
#   [203   6  11]
#   [203   6  11]
#   ...
#   [218  23  38]
#   [219  24  39]
#   [220  25  40]]
#
#  [[203   6  11]
#   [203   6  11]
#   [202   5  10]
#   ...
#   [218  23  38]
#   [218  23  38]
#   [219  24  39]]]

# %% [markdown]
# # Show each Channel

# %%
import cv2
import numpy as np

B, G, R = cv2.split(img)
 
zeros = np.zeros(img.shape[:2], dtype = "uint8")

cv2.imshow("Red", cv2.merge([zeros, zeros, R]))
cv2.waitKey(0)

cv2.imshow("Green", cv2.merge([zeros, G, zeros]))
cv2.waitKey(0)

cv2.imshow("Blue", cv2.merge([B, zeros, zeros]))
cv2.waitKey(0)

plt.imshow(cv2.cvtColor(cv2.merge([zeros, zeros, R]), cv2.COLOR_BGR2RGB))
plt.title('Red')
plt.show()

plt.imshow(cv2.cvtColor(cv2.merge([zeros, G, zeros]), cv2.COLOR_BGR2RGB))
plt.title('Green')
plt.show()

plt.imshow(cv2.cvtColor(cv2.merge([B, zeros, zeros]), cv2.COLOR_BGR2RGB))
plt.title('Blue')
plt.show()

cv2.destroyAllWindows()

# %% [markdown]
# # Resources
#
# https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_core/py_basic_ops/py_basic_ops.html#basic-ops
